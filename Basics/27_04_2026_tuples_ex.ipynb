# %%
# t1 = ()                                       
# print(t1)
# t2 = (10,20,30,40,50)
# print(t2)
# t3 = (10,10.1,"hello",True)
# print(t3)
# t4 = tuple((10,20,30,40,50))
# print(t4)
# print(type(t1))
# t5=(10)
# print(type(t5))
# t6=(10,)
# print(type(t6))
# t7=10,20,30
# print(type(t7))
# t8=10,
# print(type(t8))

# %%
# t1 = (10,20,30,40,50)
# print(t1[0])
# print(t1[-5])
# print(t1[0:3])
# print(t1[:2])
# print(t1[2:])
# print(t1[0:4:2])
# print(t1[::-2])

# %%
# t1 = (10,20,30,40,50)
# t1[0] = 100

# %%
# t1 = (10,20,30,40,50)
# list1 = list(t1)
# list1[0] = 100
# t1 = tuple(list1)
# print(t1)

# %%
t1 = (10,20,30,40,50)
# e1,e2,e3,e4,e5 = t1
# print(e5)
# e1, *t2, e5 = t1
# t2 = tuple(t2)
# print(t2)
# e2, *t3 = t2
# e3,e4 = t3
# print(e2,e3,e4)
# e1,*t2,e4,e5 = t1
# print(e4,e5)
*t2, e1,e2 = t1;
print(t2)
# Out:
# [10, 20, 30]

# %%
# 08:05AM
